# %%
from clipppy import load_config
from matplotlib import pyplot as plt
import torch, pyro, numpy as np 
import collections, os
from ruamel.yaml import YAML
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from pyro import distributions as dist

import sys
sys.path.append('/home/eliasd/lensing/elias_utils')
from plotting import *
from channels import split_channels

config = load_config('config_gen_mock_lens_source.yaml')

model = config.umodel
guide = config.guide 

PARAMS = YAML().load(open('params.yaml'))['lens_source']

# print(model().shape)
# print(model())

SYSTEM_NAME = "ngc4414"

SOURCE_DIR = '../../mock_data/sources'
source_name = f'{SYSTEM_NAME}.npy'

SAVE_DIR = "gen_obs"
n_channels  = model.n_channels
sigma_stat = model.stochastic_specs['sigma_stat']

# print(f'cmc = {cmc}, n_channels = {n_channels}, sigma_stat = {sigma_stat}')

m = model()
# Out:
# /home/eliasd/lensing/clipppy/src/clipppy/stochastic/stochastic.py:102: RuntimeWarning: Getting items from StochasticSpecs by name is frowned upon and only supports explicitly named specs at the first level that at most come from mappings (no dynamic generation).
#   warn(f'Getting items from {type(self).__name__} by name is frowned upon'

# %%
plot_imshow(m, colorbar = True)

# %%
cmc = [c() for c in model.cmc.values()][0]

# %%
def rescale(img):
    img = img - img.min()
    img = img / img.max()
    return img

# %%
# img = split_channels(m)
img = m
img = rescale(img)

plot_imshow(img, colorbar = True)

shape = img.shape
(nc, nx, ny) = tuple(shape)
img_new = torch.zeros((nx, ny, nc))

for i in range(nx):
    for j in range(ny):
        img_new[i,j] = img[:,i,j]
        
img = img_new.clone()

plot_imshow([img[:,:,0], img[:,:,1], img[:,:,2]], colorbar = True)

# %%
img_new[:,:,0] = img[:,:,1]
img_new[:,:,1] = img[:,:,2]
img_new[:,:,2] = img[:,:,0]
plt.imshow(img_new)
plot_imshow([img_new[:,:,0], img_new[:,:,1], img_new[:,:,2]], colorbar = True)

img_show = img_new.clone()
img_show2 = img_new.clone()

# %%
img_show2 = img_new.clone()
img_show2[:,:,1] -= img_show2[:,:,2] * (cmc[1])
img_show2[:,:,2] = 0
plot_imshow([img_show2[:,:,0], img_show2[:,:,1], img_show2[:,:,2]], colorbar = True)
img_show2 = rescale(img_show2)
plt.imshow(img_show2)

# %%
img_show = img_new.clone()
img_show[:,:,1] -= img_show[:,:,0] * (1-cmc[1])
img_show[:,:,0] = 0
plot_imshow([img_show[:,:,0], img_show[:,:,1], img_show[:,:,2]], colorbar = True)
img_show = rescale(img_show)
plt.imshow(img_show)

# %%
img_zero = img_show + img_show2 - img_new
plot_imshow([img_zero[:,:,0], img_zero[:,:,1], img_zero[:,:,2]], colorbar = True)

# %%
plt.imshow( rescale(img_show + img_show2) - img_new )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow( cmc[1]*img_show + img_show2 *(1-cmc[1]))

# %%
plot_imshow([img_show, img_show2, img_new])

# %%
img_show[:,:,2] -= img_show[:,:,0]
img_show[:,:,0] = 0
diff = img_show - rescale(img_show)
img_show = rescale(img_show)
plt.imshow(img_show)

# %%
plot_imshow([diff[:,:,0], diff[:,:,1], diff[:,:,2]], colorbar = True)

# %%
plot_imshow(img, colorbar = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /scratch/ipykernel_16637/1342700343.py in <module>
# ----> 1 plot_imshow(img, colorbar = True)
#
# ~/lensing/elias_utils/plotting.py in plot_imshow(plots, nrows, size_x, size_y, cmap, titles, colorbar, single_colorbar, **args)
#      29             ax.set_title(titles[i], fontsize = 10)
#      30         if colorbar == True:
# ---> 31             fig.colorbar(im, fraction=0.046, pad=0.04, ax = ax)
#      32     if single_colorbar == True:
#      33 #         fig.subplots_adjust(right=0.8)
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    1166             if (use_gridspec and isinstance(ax, SubplotBase)
#    1167                     and not self.get_constrained_layout()):
# ...

# %%
img.max()
# Out:
# tensor(8.9426)

# %%
(img - img.min()).max()
# Out:
# tensor(8.9715)

# %%
plot_imshow(img_new2, colorbar = True)

# %%
img_norm = torch.nn.functional.normalize(img_new, p = 0)

# %%
img_norm.()
# Out:
# tensor(0.0224)

# %%
plt.imshow(img_norm)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(img_new)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Out:
# torch.Size([400, 400])

# %%
img[:,0,0]
# Out:
# tensor([0.0278, 0.0461, 0.0739])

# %%
if n_channels >= 2:
    plot_imshow(split_channels(model()), size_y = 3)
    plot_imshow(split_channels(model()), size_y = 3)
if n_channels == 1:
    plot_imshow([model(), model()], size_y = 3)
# Out:
# tensor(0.5829)
# tensor(0.6357)

# %%
plot_imshow([a1[0], a2, sum(a2)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /scratch/ipykernel_6618/829644299.py in <module>
# ----> 1 plot_imshow([a1[0], a2, sum(a2)])
#
# ~/lensing/elias_utils/plotting.py in plot_imshow(plots, nrows, size_x, size_y, cmap, titles, colorbar, single_colorbar, **args)
#      25
#      26     for ax, plot, i in zip(axes_flattened, plots, range(N)):
# ---> 27         im = ax.imshow(plot, cmap = cmap[i], **args)
#      28         if titles != None:
#      29             ax.set_title(titles[i], fontsize = 10)
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
for lens in model.alphas.values():
    for lens in lens.stochastic_specs.values():
        print(lens)
# Out:
# 0.007
# 0.01
# 1.0
# 0.75
# 1.5
# 2.1
# Sampler(name='x', init=Sentinel.skip, support=Sentinel.skip, expand_by=torch.Size([]), to_event=None, indep=torch.Size([]), mask=Sentinel.skip)
# Sampler(name='y', init=Sentinel.skip, support=Sentinel.skip, expand_by=torch.Size([]), to_event=None, indep=torch.Size([]), mask=Sentinel.skip)
# /home/eliasd/lensing/clipppy/src/clipppy/stochastic/stochastic.py:129: RuntimeWarning: Iterating values from StochasticSpecs is frowned upon and returns the raw specs!
#   warn(f'Iterating values from {type(self).__name__} is frowned upon'

# %%
with pyro.poutine.trace() as tracer, pyro.condition(data=PARAMS['truth']):
    OBS = model()
OBSTRACE = tracer.trace

# %%
OBS
# Out:
# tensor([[[ 0.0327,  0.0271,  0.0342,  ...,  0.3046,  0.3189,  0.3028],
#          [ 0.0342,  0.0300,  0.0420,  ...,  0.2928,  0.2884,  0.3157],
#          [ 0.0186,  0.0306,  0.0193,  ...,  0.3005,  0.3024,  0.3186],
#          ...,
#          [ 0.3021,  0.3178,  0.3065,  ...,  0.0450,  0.0289,  0.0387],
#          [ 0.2856,  0.2839,  0.3274,  ...,  0.0418,  0.0109,  0.0250],
#          [ 0.2931,  0.3147,  0.3037,  ...,  0.0246,  0.0258,  0.0119]],
#
#         [[ 0.0190, -0.0026, -0.0012,  ...,  0.0583,  0.0532,  0.0554],
#          [ 0.0054, -0.0132, -0.0008,  ...,  0.0635,  0.0522,  0.0502],
#          [ 0.0041,  0.0097, -0.0172,  ...,  0.0444,  0.0505,  0.0419],
#          ...,
#          [ 0.0487,  0.0337,  0.0715,  ...,  0.0178,  0.0016,  0.0219],
#          [ 0.0495,  0.0436,  0.0443,  ...,  0.0103,  0.0215,  0.0110],
#          [ 0.0459,  0.0435,  0.0386,  ...,  0.0343,  0.0353,  0.0097]],
#
#         [[ 0.0195,  0.0290,  0.0191,  ...,  0.1817,  0.1755,  0.1711],
# ...

# %%
if n_channels >= 2:
    plot_imshow(split_channels(OBS), size_y = 3)
    plot_imshow(split_channels(OBS), size_y = 3)
if n_channels == 1:
    plot_imshow([OBS, OBS], size_y = 3)

# %%
keys = OBSTRACE.nodes.keys()
for k in keys: 
    print(f'{k:<15} {OBSTRACE.nodes[k]["fn"]}\n\t\t{OBSTRACE.nodes[k]["value"]}')
#     print(k, '\t', OBSTRACE.nodes[k]['fn'], '\t', OBSTRACE.nodes[k]['value'] )
# Out:
# lenslight2/x    Uniform(low: -1.0, high: 1.0)
# 		0.3
# lenslight2/y    Uniform(low: -1.0, high: 1.0)
# 		0.1
# lenslight2/index Uniform(low: 0.5, high: 2.0)
# 		1.1
# lenslight2/r_e  Uniform(low: 0.5, high: 2.0)
# 		0.9
# lenslight2/I_e  Uniform(low: 0.5, high: 2.0)
# 		1.1
# cmc2/c1         Uniform(low: 0.0, high: 1.0)
# 		0.1088441014289856
# Xsrc            MaskedDistribution()
# 		tensor([[-1.5134, -1.5037, -1.4940,  ...,  1.4551,  1.4656,  1.4761],
#         [-1.5106, -1.5008, -1.4911,  ...,  1.4526,  1.4631,  1.4737],
#         [-1.5077, -1.4980, -1.4882,  ...,  1.4501,  1.4607,  1.4712],
#         ...,
#         [-1.4476, -1.4370, -1.4265,  ...,  1.4196,  1.4297,  1.4398],
#         [-1.4502, -1.4397, -1.4291,  ...,  1.4225,  1.4326,  1.4427],
#         [-1.4528, -1.4423, -1.4318,  ...,  1.4254,  1.4355,  1.4456]])
# Ysrc            MaskedDistribution()
# 		tensor([[-1.5611, -1.5582, -1.5554,  ..., -1.5555, -1.5579, -1.5604],
# ...

# %%
# torch.save(OBS, os.path.join(SAVE_DIR,f'mock_cmc={cmc}_sigma={sigma_stat}.pt'))
# torch.save(OBS, f'mock_cmc={cmc}_sigma={sigma_stat}.pt')
torch.save(OBS, 'gen_source_lens_source.pt')
