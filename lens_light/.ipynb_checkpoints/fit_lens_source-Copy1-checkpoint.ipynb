# %%
from clipppy import load_config
from matplotlib import pyplot as plt
import torch, pyro, numpy as np 
import collections, os
import corner
from ruamel.yaml import YAML


import sys
sys.path.append('/home/eliasd/lensing/elias_utils')
from plotting import *
from channels import split_channels

# %%
VERSION_NAME = '1810_1'

STORE_DIR = 'training_data_lens_source'
STORE_DIR_VERSION = os.path.join(STORE_DIR, VERSION_NAME)
os.makedirs(STORE_DIR, exist_ok = True)
os.makedirs(STORE_DIR_VERSION, exist_ok = True)

PARAMS = YAML().load(open('params.yaml'))['lens_source']

# %%
losses_name = os.path.join(STORE_DIR_VERSION, f'losses_{VERSION_NAME}.pt')
guide_name  = os.path.join(STORE_DIR_VERSION, f'guide_{VERSION_NAME}.pt')

# %%
config = load_config('config_gen_mock_lens_source.yaml')
model = config.umodel
guide = config.guide

obs = config.conditioning['image']

# %%
if model.n_channels >= 2:
    plot_imshow(split_channels(model()), size_y = 3)
    plot_imshow(split_channels(model()), size_y = 3)
    plot_imshow(split_channels(obs), size_y = 3)
else:
    plot_imshow([model(), model(), obs, obs], size_y = 3)

# %%
from clipppy.stochastic import Sampler

def set_init(values):
    for lens in values:
        for spec in lens.stochastic_specs.values():
            if isinstance(spec, Sampler):
                name = lens.stochastic_name + '/' + spec.name
                if name in PARAMS['init']: 
                    spec.init = spec.infer['init'] = PARAMS['init'][name]
                    print(f'{name} \t set to {spec.init}')

                    
model.lenslight['sersic2'].stochastic_specs['phi'] = PARAMS['truth']['sersic2/phi']
                    
set_init(model.lenslight.values())
set_init(model.alphas.values())
set_init(model.sources.values())
# Out:
# sersic2/x 	 set to 0
# sersic2/y 	 set to 0
# sersic2/q 	 set to 1.0
# sersic2/index 	 set to 1.0
# sersic2/r_e 	 set to 1.0
# sersic2/I_e 	 set to 1.0
# ext/gamma_1 	 set to 0.0
# ext/gamma_2 	 set to 0.0
# main/phi 	 set to 0.5
# main/q 	 set to 0.5
# main/r_ein 	 set to 1.42
# main/x 	 set to 0.0
# main/y 	 set to 0.0
# /home/eliasd/lensing/clipppy/src/clipppy/stochastic/stochastic.py:113: RuntimeWarning: Setting items on StochasticSpecs by name is frowned upon and only supports explicitly named specs at the first level.
#   warn(f'Setting items on {type(self).__name__} by name is frowned upon'
# /home/eliasd/lensing/clipppy/src/clipppy/stochastic/stochastic.py:129: RuntimeWarning: Iterating values from StochasticSpecs is frowned upon and returns the raw specs!
#   warn(f'Iterating values from {type(self).__name__} is frowned upon'

# %%
# for i in range(nbatch):
#     print(f'starting batch {i}')
    
#     values = [model.lenslight.values(), model.alphas.values(), model.sources.values()]
    
#     for m in values:
#         set_init(values)
        
#     pyro.clear_param_store()
#     guide.setup()
#     losses = []

# %%
guide.setup()

guide
# Out:
# Guide(
#   (MultivariateNormal): MultivariateNormalSamplingGroup(13 sites, torch.Size([13]))
# )

# %%
if not os.path.isfile(guide_name):
    print('Training!')

    guide.train() 
    # losses += config.fit(lr=1e-2, n_steps=1000)
    losses = config.fit()
    
    torch.save(losses, losses_name)
    torch.save(guide, guide_name)

else: 
    print('Already trained!')

print('Loading!')
guide = config.guide = torch.load(guide_name)
losses = torch.load(losses_name)
# Out:
# Training!
#   0%|          | 0/5000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     173             try:
# --> 174                 ret = self.fn(*args, **kwargs)
#     175             except (ValueError, RuntimeError) as e:
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __call__(self, *args, **kwargs)
#     425         with self._pyro_context:
# --> 426             return super().__call__(*args, **kwargs)
#     427
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#
# ~/lensing/clipppy/src/clipppy/guide/guide.py in forward(self, *args, **kwargs)
#      57                 self.setup(*args, **kwargs)
# ---> 58         result = self.guide(*args, **kwargs)
#      59         return result
#
# ~/lensing/clipppy/src/clipppy/guide/guide.py in guide(self, *args, **kwargs)
#      95         # Union of all model samples dicts from self.children
# ---> 96         return dict((key, val + torch.normal(0., self.add_noise[key], val.shape)
#      97                      if key in self.add_noise else val)
#
# ~/lensing/clipppy/src/clipppy/guide/guide.py in <genexpr>(.0)
#      98                     for group in self.children() if group.active
# ---> 99                     for key, val in group()[1].items())
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __call__(self, *args, **kwargs)
#     425         with self._pyro_context:
# --> 426             return super().__call__(*args, **kwargs)
#     427
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_group.py in forward(self, infer)
#     140                     config_fn=lambda site: dict(**(infer if infer is not None else {}), is_auxiliary=True)):
# --> 141                 group_z = self._sample(infer)
#     142             return group_z, self.unpack(group_z)
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in cached_fn(self, *args, **kwargs)
#     635         with self._pyro_context:
# --> 636             return fn(self, *args, **kwargs)
#     637
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_group.py in _sample(self, infer)
#     178     def _sample(self, infer=None) -> Tensor:
# --> 179         return self.guide_z
#     180
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __get__(self, obj, obj_type)
#     155         obj.__dict__["_pyro_samples"].setdefault(self.name, self.prior)
# --> 156         return obj.__getattr__(self.name)
#     157
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __getattr__(self, name)
#     477                         if not hasattr(prior, "sample"):  # if not a distribution
# --> 478                             prior = prior(self)
#     479                         value = pyro.sample(fullname, prior)
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_group.py in guide_z(self)
#     174     def guide_z(self):
# --> 175         return self.prior()
#     176
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_groups/mvn.py in prior(self)
#      23     def prior(self):
# ---> 24         return MultivariateNormal(self.loc, scale_tril=self.scale.unsqueeze(-1) * self.corr_cholesky)
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/distributions/distribution.py in __call__(cls, *args, **kwargs)
#      17                 return result
# ---> 18         return super().__call__(*args, **kwargs)
#      19
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/distributions/multivariate_normal.py in __init__(self, loc, covariance_matrix, precision_matrix, scale_tril, validate_args)
#     145         event_shape = self.loc.shape[-1:]
# --> 146         super(MultivariateNormal, self).__init__(batch_shape, event_shape, validate_args=validate_args)
#     147
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/distributions/distribution.py in __init__(self, batch_shape, event_shape, validate_args)
#      52                 if not constraint.check(getattr(self, param)).all():
# ---> 53                     raise ValueError("The parameter {} has invalid values".format(param))
#      54         super(Distribution, self).__init__()
#
# ValueError: The parameter scale_tril has invalid values
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /scratch/ipykernel_24713/3063736123.py in <module>
#       4     guide.train()
#       5     # losses += config.fit(lr=1e-2, n_steps=1000)
# ----> 6     losses = config.fit()
#       7
#       8     torch.save(losses, losses_name)
#
# ~/lensing/clipppy/src/clipppy/commands/command.py in __call__(self, *args, **kwargs)
#      63         allowed = inspect.signature(self.forward).parameters
#      64         try:
# ---> 65             return self.forward(*args, **{
#      66                 **{key: value for key, value in self.boundkwargs.items() if key in allowed},
#      67                 **kwargs
#
# ~/lensing/clipppy/src/clipppy/commands/fit.py in forward(self, model, guide, *args, **kwargs)
#     121         with contextlib.suppress(KeyboardInterrupt), tqdm(range(self.n_steps)) as tq:
#     122             for i in tq:
# --> 123                 loss = svi.step(*args, **kwargs)
#     124                 losses.append(loss)
#     125
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/infer/svi.py in step(self, *args, **kwargs)
#     143         # get loss and compute gradients
#     144         with poutine.trace(param_only=True) as param_capture:
# --> 145             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     146
#     147         params = set(
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/infer/trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     138         loss = 0.0
#     139         # grab a trace from the generator
# --> 140         for model_trace, guide_trace in self._get_traces(model, guide, args, kwargs):
#     141             loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(
#     142                 model_trace, guide_trace
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/infer/elbo.py in _get_traces(self, model, guide, args, kwargs)
#     184         else:
#     185             for i in range(self.num_particles):
# --> 186                 yield self._get_trace(model, guide, args, kwargs)
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/infer/trace_elbo.py in _get_trace(self, model, guide, args, kwargs)
#      55         against it.
#      56         """
# ---> 57         model_trace, guide_trace = get_importance_trace(
#      58             "flat", self.max_plate_nesting, model, guide, args, kwargs
#      59         )
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/infer/enum.py in get_importance_trace(graph_type, max_plate_nesting, model, guide, args, kwargs, detach)
#      50     and the model that is run against it.
#      51     """
# ---> 52     guide_trace = poutine.trace(guide, graph_type=graph_type).get_trace(*args, **kwargs)
#      53     if detach:
#      54         guide_trace.detach_()
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/poutine/trace_messenger.py in get_trace(self, *args, **kwargs)
#     196         Calls this poutine and returns its trace instead of the function's return value.
#     197         """
# --> 198         self(*args, **kwargs)
#     199         return self.msngr.get_trace()
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     178                 exc = exc_type(u"{}\n{}".format(exc_value, shapes))
#     179                 exc = exc.with_traceback(traceback)
# --> 180                 raise exc from e
#     181             self.msngr.trace.add_node(
#     182                 "_RETURN", name="_RETURN", type="return", value=ret
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     172             )
#     173             try:
# --> 174                 ret = self.fn(*args, **kwargs)
#     175             except (ValueError, RuntimeError) as e:
#     176                 exc_type, exc_value, traceback = sys.exc_info()
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __call__(self, *args, **kwargs)
#     424     def __call__(self, *args, **kwargs):
#     425         with self._pyro_context:
# --> 426             return super().__call__(*args, **kwargs)
#     427
#     428     def __getattr__(self, name):
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/lensing/clipppy/src/clipppy/guide/guide.py in forward(self, *args, **kwargs)
#      56             with poutine.block():
#      57                 self.setup(*args, **kwargs)
# ---> 58         result = self.guide(*args, **kwargs)
#      59         return result
#      60
#
# ~/lensing/clipppy/src/clipppy/guide/guide.py in guide(self, *args, **kwargs)
#      94     def guide(self, *args, **kwargs) -> MutableMapping[str, torch.Tensor]:
#      95         # Union of all model samples dicts from self.children
# ---> 96         return dict((key, val + torch.normal(0., self.add_noise[key], val.shape)
#      97                      if key in self.add_noise else val)
#      98                     for group in self.children() if group.active
#
# ~/lensing/clipppy/src/clipppy/guide/guide.py in <genexpr>(.0)
#      97                      if key in self.add_noise else val)
#      98                     for group in self.children() if group.active
# ---> 99                     for key, val in group()[1].items())
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __call__(self, *args, **kwargs)
#     424     def __call__(self, *args, **kwargs):
#     425         with self._pyro_context:
# --> 426             return super().__call__(*args, **kwargs)
#     427
#     428     def __getattr__(self, name):
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_group.py in forward(self, infer)
#     139             with pyro.poutine.infer_config(
#     140                     config_fn=lambda site: dict(**(infer if infer is not None else {}), is_auxiliary=True)):
# --> 141                 group_z = self._sample(infer)
#     142             return group_z, self.unpack(group_z)
#     143
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in cached_fn(self, *args, **kwargs)
#     634     def cached_fn(self, *args, **kwargs):
#     635         with self._pyro_context:
# --> 636             return fn(self, *args, **kwargs)
#     637
#     638     return cached_fn
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_group.py in _sample(self, infer)
#     177     @pyro_method
#     178     def _sample(self, infer=None) -> Tensor:
# --> 179         return self.guide_z
#     180
#     181
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __get__(self, obj, obj_type)
#     154
#     155         obj.__dict__["_pyro_samples"].setdefault(self.name, self.prior)
# --> 156         return obj.__getattr__(self.name)
#     157
#     158
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/nn/module.py in __getattr__(self, name)
#     476                     if value is None:
#     477                         if not hasattr(prior, "sample"):  # if not a distribution
# --> 478                             prior = prior(self)
#     479                         value = pyro.sample(fullname, prior)
#     480                         context.set(fullname, value)
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_group.py in guide_z(self)
#     173     @PyroSample
#     174     def guide_z(self):
# --> 175         return self.prior()
#     176
#     177     @pyro_method
#
# ~/lensing/clipppy/src/clipppy/guide/sampling_groups/mvn.py in prior(self)
#      22
#      23     def prior(self):
# ---> 24         return MultivariateNormal(self.loc, scale_tril=self.scale.unsqueeze(-1) * self.corr_cholesky)
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/pyro/distributions/distribution.py in __call__(cls, *args, **kwargs)
#      16             if result is not None:
#      17                 return result
# ---> 18         return super().__call__(*args, **kwargs)
#      19
#      20     @property
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/distributions/multivariate_normal.py in __init__(self, loc, covariance_matrix, precision_matrix, scale_tril, validate_args)
#     144
#     145         event_shape = self.loc.shape[-1:]
# --> 146         super(MultivariateNormal, self).__init__(batch_shape, event_shape, validate_args=validate_args)
#     147
#     148         if scale_tril is not None:
#
# ~/.pyenv/versions/3.9.7/envs/lens-3.9.7/lib/python3.9/site-packages/torch/distributions/distribution.py in __init__(self, batch_shape, event_shape, validate_args)
#      51                     continue  # skip checking lazily-constructed args
#      52                 if not constraint.check(getattr(self, param)).all():
# ---> 53                     raise ValueError("The parameter {} has invalid values".format(param))
#      54         super(Distribution, self).__init__()
#      55
#
# ValueError: The parameter scale_tril has invalid values
#                    Trace Shapes:
#                     Param Sites:
#           MultivariateNormal.loc    13
#         MultivariateNormal.scale    13
# MultivariateNormal.corr_cholesky 13 13
#                    Sample Sites:

# %%
plot_log(losses, size_y = 3)

# %%
def plot_guide(nsamples = 1000):
    
    params = PARAMS['truth']
    
    
    with pyro.plate('plate', nsamples):
        ppd = config.guide()
    
    ppd = {key: val for key, val in ppd.items()}
    labels = [f'{name}={truth:.2f}' for name, truth in params.items()]
    truths = [params.get(k, None) for k in ppd.keys()]
    
    print(f'{"parameter":<15} {"truth":<8} {"mean":17} {"sigma?"}')
    for (k, v), truth in zip(ppd.items(), truths): 
        print(f'{k:<15} {truth:<7} {v.mean():+.5f} ± {v.std():.5f} ({truth}{v.mean()-truth:+f}: {abs((truth - v.mean()) / v.std()):.1f}-sigma)')
    


    return corner.corner( np.stack([v.detach().numpy() for v in ppd.values()], -1), 
                         truths = truths, labels = labels);


plot_guide();

# %%
def plot_fit_resids(nsamples = 1000):
    pred = torch.stack([config.ppd()['model_trace'].nodes['mu']['value'] for i in range(nsamples)], 0).mean(0)
        
#     obs = config.conditioning['image']
        
    if model.n_channels >= 2:
        obss  = split_channels(obs)
        preds = split_channels(pred)
        diffs = (obss - preds)
        plots = torch.cat((obss, preds, diffs))
        titles = ['truth c_1', 'truth c_2', 'truth total', 'pred c_1', 'pred c_2', 'pred total', 'diff c_1', 'diff c_2', 'diff total']
        return plot_imshow(plots = plots, nrows = 3, colorbar = True, titles = titles)
    
    else:
        plots = [obs, pred, obs - pred]
        titles = ['truth', 'mu pred', 'diff truth and mu pred', 'truth', 'mode pred', 'diff truth and mode pred', 'truth', 'mean pred', 'diff truth and mean pred', 'mode pred', 'mean pred', 'diff mode pred and mean pred']
    
        return plot_imshow(plots = plots, colorbar = True, titles = titles)

plot_fit_resids(10)
